# %% [markdown]
# # 1-Stage Detector

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 특징
# - Localization, Classification이 동시에 진행
# - 전체 이미지에 대해 특징 추출, 객체 검출이 이루어짐 → 간단하고 쉬운 디자인
# - 속도가 매우 빠름 (Real-time detection)
# - 영역을 추출하지 않고 전체 이미지를 보기 때문에 객체에 대한 맥락적 이해가 높음
# - Background error가 낮음

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### YOLO 버젼별 특징
#
# - YOLO v1 : 하나의 이미지의 Bbox와 classification을 동시에 여측하는 1-stage detector
# - YOLO v2 : Better, Faster, Stronger
# - YOLO v3 : multi-scale feature maps 사용
# - YOLO v4 : BOF(Bag of Freebies), BOS(Bag of Specials) 사용
# - YOLO v5 : 크기별로 모델 구성(Small, Medium, Large, Xlarge)

# %% [markdown]
# ### 1 Stage Detector 연구 동향 및 Paper
# - Anchor
#   - [DAFS]Dynamic Anchor Feature Selection for Single-Shot Object Detection
#   - [FSAF]Feature Selective Anchor-Free Module for Single-Shot Object Detection
# - Multi-Scale Feature Map
#   - M2Det: A Single-Shot Object Detector based on Multi-Level Feature Pyramid Network
#   - Learning Rich Features at High-Speed for Single-Shot Object Detection
# - 경량화
#   - YOLOv4: Optimal Spped and Accuracy of Object Detection
#   - Scaled-YOLOv4: Scaling Cross Stage Partial Network

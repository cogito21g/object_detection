# %% [markdown]
# # SPPNet

# %% [markdown]
# ### 개요
# - R-CNN의 한계점
#   - Convolution Network의 입력 이미지가 고정되어 있음 -> 이미지를 crop/wrap해야 함
#   - RoI마다 CNN 통과 -> 시간이 오래 걸림
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 특징
# - CNN, SVM classifier, Bounding Box Regressor 따로 학습
# - End-to-End(x)

# %% [markdown]
# ### Architecture
# - R-CNN과 SPPNet 비교
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Spatial Pyramid Pooling
#
# ![image.png](attachment:image.png)
